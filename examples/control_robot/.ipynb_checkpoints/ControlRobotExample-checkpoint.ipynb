# %%
using Gen
using PyPlot

# %%
function desired_next_step(u::String, x::Float64, y::Float64)
    if u == "U"
        y += 1.
    elseif u == "D"
        y += -1.
    elseif u == "R"
        x += 1.
    elseif u == "L"
        x += -1.
    end
    return x,y
end
# Out:
# WARNING: Method definition desired_next_step(String, Float64, Float64) in module Main at In[67]:2 overwritten at In[69]:2.
# desired_next_step (generic function with 3 methods)

# %%
#each index matches whether it was broken or not on that location. For instance the first position is always not
function controlled_robot_program(T::Trace, user_controls::Array{String,1})
    possible_controls = ["R","U","L","D"]
    
    curr_x = 0.
    curr_y = 0.
    
    b = []
    
    for i=1:length(user_controls)
        if i != 1 && b[i-1]
            push!(b, flip(1) ~ "b$i") 
        else
            push!(b, flip(0.2) ~ "b$i")
        end
        
        println("b: $b")
        
        if b[i]
            #randomly sample new control
            u = possible_controls[rand(1:4)]
        else
            u = user_controls[i] # R, U, L , or D
        end
        
        println("real u: $(user_controls[i])")
        println("obsv u: $u")
        
        #Gives the position of what the next desired step is
        desired_x, desired_y = desired_next_step(u, curr_x, curr_y) 
        println("desired_x: $desired_x")
        println("desired_y: $desired_y")
        
        #Add some noise to the desired next step
        curr_x = normal(desired_x, 0.075) ~ "x$i"
        curr_y = normal(desired_y, 0.075) ~ "y$i"
        
        println("x: $curr_x")
        println("y: $curr_y")
        println("-----------")
    end
end
# Out:
# WARNING: Method definition controlled_robot_program(Gen.Trace, Array{String, 1}) in module Main at In[296]:4 overwritten at In[298]:4.
# controlled_robot_program (generic function with 2 methods)

# %%
u = ["R","U","L","D"]
robot_trace = Trace()
controlled_robot_program(robot_trace, u)
println("robot_trace: $(robot_trace.log_weight)")
# Out:
# b: Any[false]
# real u: R
# obsv u: R
# desired_x: 1.0
# desired_y: 0.0
# x: 0.9708788869102112
# y: -0.1045488402534016
# -----------
# b: Any[false,false]
# real u: U
# obsv u: U
# desired_x: 0.9708788869102112
# desired_y: 0.8954511597465984
# x: 0.8731314895900786
# y: 0.931469038872878
# -----------
# b: Any[false,false,false]
# real u: L
# obsv u: L
# desired_x: -0.12686851040992142
# desired_y: 0.931469038872878
# x: -0.2006951712538078
# y: 0.9223076606584367
# -----------
# b: Any[false,false,false,false]
# real u: D
# obsv u: D
# desired_x: -0.2006951712538078
# desired_y: -0.07769233934156328
# x: -0.1564018381235697
# y: -0.1655454841117766
# -----------
# robot_trace: 0.0

# %%
using Distributions

P = (log(0.8)+log(0.8)+log(0.8)+log(0.8))
dx = [1.0,0.9708788869102112,-0.12686851040992142,-0.2006951712538078]
dy = [0.0,0.8954511597465984,0.931469038872878,-0.07769233934156328]
rx = map((i) -> robot_trace["x$i"], 1:length(u))
ry = map((i) -> robot_trace["y$i"], 1:length(u))
for i=1:4
    P += logpdf(Normal(dx[i], 0.075), rx)
    P += logpdf(Normal(dy[i], 0.075), ry)
end
    
println(P)
# Out:
# MethodError: no method matching Distributions.Normal{T<:Real}(::Float64, ::Float64, ::Array{Float64,1})
# Closest candidates are:
#   Distributions.Normal{T<:Real}{T<:Real}(::T<:Real, ::T<:Real) at /Users/Iris/.julia/v0.5/Distributions/src/univariate/continuous/normal.jl:32
#   Distributions.Normal{T<:Real}(::Real, ::Real) at /Users/Iris/.julia/v0.5/Distributions/src/univariate/continuous/normal.jl:33
#   Distributions.Normal{T<:Real}(::Real) at /Users/Iris/.julia/v0.5/Distributions/src/univariate/continuous/normal.jl:35
#   ...
#
#  in macro expansion; at ./In[315]:9 [inlined]
#  in anonymous at ./<missing>:?

# %%
println(length(observed_xs))
plt[:figure](figsize=(5, 5))

zero_start_xs = [0.]
zero_start_ys = [0.]

zero_start_xs = vcat(zero_start_xs, map((i) -> robot_trace["x$i"], 1:length(u)))
zero_start_ys = vcat(zero_start_ys, map((i) -> robot_trace["y$i"], 1:length(u)))

bs = map((i) -> robot_trace["b$i"], 1:length(u))
broken_index = findfirst(bs, true)
if broken_index != 0
    plt[:plot](zero_start_xs[1:broken_index], zero_start_ys[1:broken_index], color="blue", lw=3)
    plt[:plot](zero_start_xs[broken_index:end], zero_start_ys[broken_index:end], color="red", lw=3)
else
    plt[:plot](zero_start_xs, zero_start_ys, color="blue", lw=3)
end

plt[:xlim](-4,4)
plt[:ylim](-4,4)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32663d310>)
# 36
# (-4,4)

# %%
function render_observed_path_trace(trace::Trace,
                                         xs::Array{Float64,1}, ys::Array{Float64,1},
                                         ax, xlim, ylim)
    
    zero_start_xs = [0.]
    zero_start_ys = [0.]

    zero_start_xs = vcat(zero_start_xs, xs)
    zero_start_ys = vcat(zero_start_ys, ys)

    bs = map((i) -> trace["b$i"], 1:length(xs))
    broken_index = findfirst(bs, true)
    if broken_index != 0
        ax[:plot](zero_start_xs[1:broken_index], zero_start_ys[1:broken_index], color="blue", lw=3)
        ax[:plot](zero_start_xs[broken_index:end], zero_start_ys[broken_index:end], color="red", lw=3)
    else
        ax[:plot](zero_start_xs, zero_start_ys, color="blue", lw=3)
    end

    ax[:set_xlim](xlim)
    ax[:set_ylim](ylim)
    
end
# Out:
# WARNING: Method definition render_observed_path_trace(Gen.Trace, Array{Float64, 1}, Array{Float64, 1}, Any, Any, Any) in module Main at In[256]:5 overwritten at In[281]:5.
# render_observed_path_trace (generic function with 1 method)

# %%
traces = []
u = ["R","U","L","D"]
log_weights = []
observed_xs = []
observed_ys = []
for replicate=1:36
    trace = Trace()
    controlled_robot_program(trace, u)
    push!(observed_xs, map((i) -> trace["x$i"], 1:length(u)))
    push!(observed_ys, map((i) -> trace["y$i"], 1:length(u)))
    push!(traces, trace)
    push!(log_weights, trace.log_weight)
end

# %%
plt[:figure](figsize=(18, 8))
for (i, trace) in enumerate(traces)
    plt[:subplot](4, 9, i)
    ax = plt[:gca]()
    xlim = [-2., 2.]
    ylim = [-2., 2.]
    ax[:title][:set_text](log_weights[i])
    render_observed_path_trace(trace, observed_xs[i], observed_ys[i], ax, xlim, ylim)
end
plt[:tight_layout]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3255b0710>)

# %%
observed_xs = Array{Float64,1}(0)
# Out:
# 0-element Array{Float64,1}
